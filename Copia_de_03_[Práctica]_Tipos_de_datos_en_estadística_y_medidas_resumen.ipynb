# %% [markdown]
# <a href="https://colab.research.google.com/github/juan-lawrie/Repaso-Ciencias-de-datos/blob/main/Copia_de_03_%5BPr%C3%A1ctica%5D_Tipos_de_datos_en_estad%C3%ADstica_y_medidas_resumen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📌 Tema 3 Práctica: Tipos de datos en estadística y medidas resumen

# %% [markdown]
# ❗Antes de comenzar con la clase, hacete una copia de este documento así podés editarlo y guardar los cambios.
#
# Hacé clic acá arriba, donde dice "Copiar en Drive".
#
# Luego seguís trabajando en esa copia y te queda todo guardado en tu Drive.

# %% [markdown]
# ***Se realizará una puesta en común en clase de los ejercicios 2, 4, 6, 7, 8, 9 y 10.*** 🚀

# %% [markdown]
# ## 📝 Ejercicio 1

# %% [markdown]
# En cada situación de las que se enumeran abajo:
# - Clasificá el tipo de dato que se registra: cuantitativo (continuo o discreto) o cualitativo (nominal u ordinal).
# - Indicá los posibles valores o categorías de ese tipo de dato.
# - Identificá cuáles son las unidades experimentales.

# %% [markdown]
# Situaciones:
#
# 1. En una fábrica, los productos se clasifican según su calidad en: muy mala, mala, regular, buena, muy buena, excelente.
# 2. Un estudio mide el tiempo de duración de distintas películas en horas y minutos.
# 3. En una escuela, se registran los cargos del personal, como director/a, vicedirector/a, regente, profesor/a.
# 4. Un censo cuenta cuántos animales de compañía hay en cada hogar.
# 5. En una ciudad se mide cuántas toneladas de residuos se reciclan cada mes.
# 6. Un estudio clasifica a las empresas según el sector al que pertenecen: agricultura, industria, comercio o servicios.
# 7. Un informe registra el consumo de electricidad de los electrodomésticos en kilovatios-hora (kWh).
# 8.  En una votación, se le pregunta a las personas si votaron a favor de una nueva ley o no.
# 9. Un servicio meteorológico mide la cantidad de lluvia en distintas ciudades durante el verano, expresada en milímetros.
# 10. Una plataforma de transmisión de contenido permite calificar una película con las opciones: mala, regular, buena, excelente.

# %% [markdown]
# ✏️ Respuestas:
#
# 1. Cualitativo nominal. Los posibles valores son muy mala, mala, regular, buena, muy buena, excelente. y la unidad experimental son los productos que produce la fabrica.
# 2. Cuantitativo continuo. Unidad experimental las películas. Posibles valores tiempo en horas y minutos.
# 3. Cualitativo ordinal,posibles valores director/a, vicedirector/a, regente, profesor/a,unidad experimental es cada integrante del personal de la escuela.
# 4. Cuantitativo discreto, posibles valores cantidad de animales de compañia por hogar, unidad experimental cada hogar censado.
# 5. Cuantitativo continuo, posibles valores cantidad de toneladas que se reciclan cada mes.Unidad experimental cantidad reciclada en una ciudad cada mes
# 6. Cualitativo nominal, posibles valores agricultura, industria, comercio o servicios, unidades experimentales es cada uno de los elementos individuales que observás para obtener un dato.
# 7. Cuantitativo continuo, posibles valores  kilovatios-hora (kWh). Unidades experimentales cada electrodomestico
# 8. Cualitativa nominal. Posibles valores a favor o en contra. Unidades experimentales cada persona preguntada acerca de como voto
# 9. Cuantitativa continua, Posibles valores numeros reales positivos.Unidades experimentales cada ciudad.
# 10.Cualitativa nominal, posibles valores mala, regular, buena, excelente. Unidades experimentales la/s pelicula/s

# %% [markdown]
# ---

# %% [markdown]
# Luego, a partir de los siguientes conjuntos de datos:
#
# 1. *Calidad de productos*: buena, buena, regular, excelente, buena, mala, muy buena, regular, excelente, mala.
# 2. *Cargos del personal escolar*: profesor/a, profesor/a, director/a, regente, profesor/a, vicedirector/a, regente, profesor/a.
# 3. *Número de mascotas por hogar*: 0, 2, 1, 3, 2, 4.
# 4. *Cantidad de lluvia (en mm) en distintas ciudades*: 12.3, 48.5, 25.0, 33.2, 29.0.
#
# ✍️ Realizá lo siguientes cálculos con **lápiz y papel** según corresponda:
# - Para los datos cualitativos: calculá las frecuencias absolutas y relativas. Buena se repita:  3
# Regular se repite:  2
# excelente se repite:  2
# mala se repite:  2
# muy buena se repite:  1
# - Para los datos cuantitativos: calculá las medidas de centro (media y mediana) y dispersión (rango y desvío estándar). La media es 2.La mediana es 2. El rango es 4. Desvío estándar 1.2909944487358056

# %% [markdown]
# ✏️ Respuestas:
#
# 1. ...
# 2. ...
# 3. ...
# 4. ...

# %% [markdown]
# ## 📝 Ejercicio 2

# %% [markdown]
# Una cafetería registró la frecuencia relativa de las bebidas más pedidas en un día. Los datos obtenidos son los siguientes:
#
# |Bebida|Frecuencia relativa|
# |:--|:--|
# |Café|0.50|
# |Té|0.25|
# |Jugo|0.15|
# |Chocolate|0.10|
#
# Respondé las siguientes preguntas:
# - ¿Qué tipo de dato está registrado en la tabla? ¿Cuantitativo o cualitativo? ¿Discreto/continuo o nominal/ordinal? Cualitativo nominal y Cuantitativo continuo
# - ¿Cuáles son las unidades experimentales? Las bebidas
# - Si se vendieron 200 bebidas en total, ¿cuántas unidades se vendieron de cada bebida.  100 Cafés,50 Tés, 30 jugos y 20 chocolates.
#
# Completá el código para responder esta última pregunta:

# %%
# Frecuencias relativas
frecuencia_cafe = 0.50
frecuencia_te =0.25
frecuencia_jugo = 0.15
frecuencia_chocolate = 0.10

# Total de bebidas vendidas
total_bebidas = 200

# Calculá las unidades vendidas de cada bebida
cantidad_cafe = frecuencia_cafe * total_bebidas
cantidad_te = frecuencia_te * total_bebidas
cantidad_jugo = frecuencia_jugo * total_bebidas
cantidad_chocolate = frecuencia_chocolate * total_bebidas

# Mostrá los resultados
print("Café:", cantidad_cafe)
print("Té:", cantidad_te)
print("Jugo:", cantidad_jugo)
print("Chocolate:",cantidad_chocolate )
# Out:
# Café: 100.0
# Té: 50.0
# Jugo: 30.0
# Chocolate: 20.0

# %% [markdown]
# A partir de los resultados anteriores, ¿cuántas bebidas no contienen cafeína (té y jugo)?

# %%
bebidas_sin_cafeina = cantidad_te +
print("Bebidas sin cafeína (té y jugo):", )

# %% [markdown]
# Si al día siguiente se vendieron 300 bebidas manteniendo la misma distribución de frecuencias relativas, ¿cuántos cafés se vendieron?

# %%
total_bebidas_dia_siguiente = 300
cantidad_cafe_dia_siguiente = 150
print("Cafés vendidos al día siguiente:",cantidad_cafe_dia_siguiente)
# Out:
# Cafés vendidos al día siguiente: 150

# %% [markdown]
# ## 📝 Ejercicio 3

# %% [markdown]
# En un supermercado se registraron los productos más comprados por los clientes durante una semana, y los resultados son los siguientes:
#
# - **Lácteos**: Leche (50 compras), Huevos (35 compras)
# - **Frutas**: Manzanas (30 compras), Bananas: (25 compras)
# - **Verduras**: Tomates (40 compras), Lechuga (30 compras), Zanahorias (20 compras)
#
# Calculá la **frecuencia absoluta y relativa por tipo de producto** (lácteos, frutas, y verduras):

# %%
# Datos de compras
leche = 50
huevos = 35
manzanas = 30
bananas = 25
tomates = 40
lechuga = 30
zanahorias = 20

# Total de compras
total_compras = manzanas + bananas + leche + huevos+ tomates + lechuga + zanahorias

# %%
# Frecuencias por tipo de producto

# Lácteos
lacteos_total = leche
frecuencia_relativa_lacteos = (leche / 1)

# Frutas
frutas_total = manzanas + bananas + tomates
frecuencia_relativa_frutas =(frutas_total/3)

# Verduras
verduras_total = lechuga + zanahorias
frecuencia_relativa_verduras = (verduras_total/2)

# %%
print("Frecuencia absoluta de Lácteos:", lacteos_total)
print("Frecuencia absoluta de Frutas:", verduras_total)
print("Frecuencia absoluta de Verduras:", verduras_total)
# Out:
# Frecuencia absoluta de Lácteos: 50
# Frecuencia absoluta de Frutas: 50
# Frecuencia absoluta de Verduras: 50

# %%
print("Frecuencia relativa de Lácteos:", frecuencia_relativa_lacteos)
print("Frecuencia relativa de Frutas:", frecuencia_relativa_frutas)
print("Frecuencia relativa de Verduras:", frecuencia_relativa_verduras)
# Out:
# Frecuencia relativa de Lácteos: 50.0
# Frecuencia relativa de Frutas: 31.666666666666668
# Frecuencia relativa de Verduras: 25.0

# %% [markdown]
# 📌 Preguntas:
# 1. ¿Cuál es el producto más comprado? ¿Y el menos comprado?
# 2. ¿Qué tipo de producto es el más comprado? ¿Y el tipo menos comprado?

# %% [markdown]
# ✏️ Respuestas:
#
# 1. El mas comprado es la leche. El menos comprado son las zanahorias.
# 2. El tipo de producto mas comprado es un lacteo. El tipo de producto menos comprado es una verdura.

# %% [markdown]
# ## 📝 Ejercicio 4

# %% [markdown]
# En una universidad se registraron las carreras elegidas por de un grupo de 280 estudiantes. Las carreras que se dictan son tres: Ingeniería, Medicina y Psicología. Se conocen los datos de Ingeniería y Medicina, pero no de Psicología.
#
# Tu tarea será calcular las frecuencias absolutas y relativas de la carrera de Psicología.
#
# Los datos de las carreras son los siguientes:
# - **Ingeniería**:
#     - Frecuencia absoluta: 126 estudiantes
#     - Frecuencia relativa: 45%
# - **Medicina**:
#     - Frecuencia absoluta: 98 estudiantes
#     - Frecuencia relativa: 35%
# - **Psicología**:
#     - Frecuencia absoluta: ?
#     - Frecuencia relativa: ?
#
# A partir del siguiente código:

# %%
frecuencia_ingenieria = 126
frecuencia_relativa_ingenieria = 0.45
frecuencia_medicina = 98
frecuencia_relativa_medicina = 0.35

# %% [markdown]
# Calculá la frecuencia absoluta de Psicología a partir de las frecuencias absolutas de las otras dos carreras:

# %%
frecuencia_psicologia = (frecuencia_ingenieria + frecuencia_medicina)-280
frecuencia_absoluta_psicologia = 56

# %% [markdown]
# Calculá la frecuencia relativa de Psicología a partir de las frecuencias relativas de las otras dos carreras:

# %%
frecuencia_relativa_psicologia = frecuencia_absoluta_psicologia /280

# %%
print("Frecuencia absoluta de Psicología:", frecuencia_absoluta_psicologia)
print("Frecuencia relativa de  Psicología: ", frecuencia_relativa_psicologia )
# Out:
# Frecuencia absoluta de Psicología: 56
# Frecuencia relativa de  Psicología:  0.2

# %% [markdown]
# ¿Qué habria que cambiar en este último cálculo si las frecuencias relativas estuvieran representadas en porcentaje? En vez de poner numeros entre 0 y 1 habria que poner numeros entre 1 y 100 con % de porcentaje

# %% [markdown]
# ## 📝 Ejercicio 5

# %% [markdown]
# Observá el código en la celda a continuación:

# %%
productos_turno_1 = 120
productos_turno_2 = 150
productos_turno_3 = 130
productos_turno_4 = 140

total_productos = productos_turno_1 + productos_turno_2 + productos_turno_3 + productos_turno_4

umbral_superior = 550
umbral_inferior = 450

if total_productos > umbral_superior:
    estado_produccion = "Muy alta"
elif total_productos < umbral_inferior:
    estado_produccion = "Muy baja"
else:
    estado_produccion = "Dentro del rango esperado"

print("Total de productos fabricados:", total_productos)
print("Estado de la producción:", estado_produccion)
# Out:
# Total de productos fabricados: 540
# Estado de la producción: Dentro del rango esperado

# %% [markdown]
# 📌 Preguntas:
#
# 1. ¿Qué tipo de dato estadístico se está representando en `productos_turno_X` y `estado_produccion`?
# 2. Explicá con tus palabras lo que hace el código.

# %% [markdown]
# ✏️ Respuestas:
#
# 1. Estado_produccion es cualitativo ordinal. productos_turnos es cuantitativo discreto
# 2. ...

# %% [markdown]
# Calculá la media de productos fabricados por turno:

# %%
media_productos =
print("Media de productos fabricados por turno:", )

# %% [markdown]
# Ahora es momento de analizar la producción de cada turno con la media.
#
# Calculá si cada turno tiene una producción por encima o por debajo de la media:

# %%
# Compará la producción de cada turno con la media
encima_turno_1 = productos_turno_1 >
encima_turno_2 =
encima_turno_3 =
encima_turno_4 =

# Mostrá los resultados
print("Producción por encima de la media:")
print("Turno 1:", encima_turno_1)
print("Turno 2:", )
print("Turno 3:", )
print("Turno 4:", )

# %% [markdown]
# ¿Qué tipo de dato estadístico se está representando en `encima_turno_X`?

# %% [markdown]
# ## 📝 Ejercicio 6

# %% [markdown]
# En una empresa se registraron los ingresos mensuales (en miles de pesos) de 7 empleados. Se desea calcular tanto la media como la mediana de los ingresos. Sin embargo, el código que se presenta contiene algunos errores.
#
# Corregí todos los errores para que los cálculos sean correctos:

# %%
# Datos de ingresos
ingreso_empleado_1 = 350
ingreso_empleado_2 = 500
ingreso_empleado_3 = 250
ingreso_empleado_4 = 450
ingreso_empleado_5 = 300
ingreso_empleado_6 = 6000
ingreso_empleado_7 = 1200

# Media
n = 7
total_ingresos = ingreso_empleado_1 + ingreso_empleado_2 + ingreso_empleado_2 + ingreso_empleado_4 + ingreso_empleado_5 + ingreso_empleado_6 + ingreso_empleado_7
media_ingresos = total_ingresos // n

# Mediana
ingresos_ordenado1 = ingreso_empleado_5
ingresos_ordenado2 = ingreso_empleado_3
ingresos_ordenado3 = ingreso_empleado_1
ingresos_ordenado4 = ingreso_empleado_4
ingresos_ordenado5 = ingreso_empleado_2
ingresos_ordenado6 = ingreso_empleado_6
ingresos_ordenado7 = ingreso_empleado_7

pos_mediana = (n + 1) // 2

if pos_mediana == 1:
    mediana_ingresos = ingresos_ordenado1
elif pos_mediana == 2:
    mediana_ingresos = ingresos_ordenado2
elif pos_mediana == 3:
    mediana_ingresos = ingresos_ordenado4
elif pos_mediana == 4:
    mediana_ingresos = ingresos_ordenado3
elif pos_mediana == 5:
    mediana_ingresos = ingresos_ordenado5
elif pos_mediana == 60:
    mediana_ingresos = ingresos_ordenado6
else:
    mediana_ingresos = ingresos_ordenado7

# Resultados
print("Media de ingresos:", mediana_ingresos)
print("Mediana de ingresos:", media_ingresos)
# Out:
# Media de ingresos: 350
# Mediana de ingresos: 1328

# %% [markdown]
# 📌 Preguntas:
#
# 1. ¿Qué tipo de dato estadístico representa el ingreso de cada empleado?
# 2. ¿Cuál medida (media o mediana) es más representativa de los ingresos en este caso? Explicá por qué.

# %% [markdown]
# ✏️ Respuestas:
#
# 1. Cuantitativo continuo
# 2. Mediana

# %% [markdown]
# ## 📝 Ejercicio 7

# %% [markdown]
# En la ciudad de Santa Fe, se registraron las temperaturas medias estacionales (en °C) en un año determinado:
#
# - 🌸 Primavera: 20°C
# - ☀️ Verano: 25°C
# - 🍂 Otoño: 18°C
# - ❄️ Invierno: 12°C
#
# Calculá el **rango** de temperaturas (diferencia entre la máxima y la mínima):

# %%
temp_primavera = 20
temp_verano = 25
temp_otono = 18
temp_invierno = 12

max_temp = temp_verano
min_temp = temp_invierno

rango_temp = temp_verano - temp_invierno

print("Temperatura máxima: ", max_temp, "°C")
print("Temperatura mínima: ", min_temp, "°C")
print("Rango de temperaturas:", rango_temp, "°C")
# Out:
# Temperatura máxima:  25 °C
# Temperatura mínima:  12 °C
# Rango de temperaturas: 13 °C

# %% [markdown]
# Calculá la **variación relativa** de temperatura entre estaciones en porcentaje. Esto es:
# - Primavera → Verano
# - Verano → Otoño
# - Otoño → Invierno
#
# Por ejemplo, para el caso Primavera → Verano, la variación relativa se calcularía como:
#
# $$ \frac{25 - 20}{20} \times 100$$

# %%
variacion_primavera_verano = ((temp_verano - temp_primavera) / 20) * 100
variacion_verano_otono =      ((temp_verano - temp_otono) / 18) * 100
variacion_otono_invierno =   ((temp_otono - temp_invierno) / 12) * 100

print("Variación de Primavera a Verano:", variacion_primavera_verano, "%")
print("Variación de Verano a Otoño:", variacion_verano_otono, "%")
print("Variación de Otoño a Invierno:", variacion_otono_invierno, "%")
# Out:
# Variación de Primavera a Verano: 25.0 %
# Variación de Verano a Otoño: 38.88888888888889 %
# Variación de Otoño a Invierno: 50.0 %

# %% [markdown]
# Ahora, se registraron las temperaturas medias de dos meses de verano y sus valores son:
# - Enero: 26°C
# - Febrero: 25°C
#
# Utilizando la temperatura media de verano y las temperaturas de Enero y Febrero, estimá la temperatura de **Marzo**:

# %%
temp_enero = 26
temp_febrero = 25

temp_marzo = (temp_verano * 3) - (temp_enero  + temp_febrero)

print("Temperatura estimada para marzo:", temp_marzo , "°C")
# Out:
# Temperatura estimada para marzo: 24 °C

# %% [markdown]
# 📌 Preguntas:
#
# 1. ¿Qué nos dice el valor obtenido del **rango** sobre la variabilidad del clima en Santa Fe?
# 2. ¿En qué transición de estación se produce la mayor **variación relativa**? ¿Y la menor?
# 3. ¿La temperatura estimada de **Marzo** es coherente con la media de verano?

# %% [markdown]
# ✏️ Respuestas:
#
# 1. ...
# 2. ...
# 3. ...

# %% [markdown]
# ## 📝 Ejercicio 8

# %% [markdown]
# En una pista de carreras, se registraron los tiempos de vuelta de dos pilotos durante cuatro intentos.
#
# Los tiempos en segundos son los siguientes:
#
# - **Piloto A**: 78.2 s, 79.0 s, 78.5 s, 77.8 s
# - **Piloto B**: 78.0 s, 80.2 s, 77.5 s, 79.5 s
#
# Tareas:
# - Calculá la **media** de los tiempos de vuelta para cada piloto.
# - Calculá el **desvío estándar** de los tiempos de vuelta para cada piloto.

# %%
# Tiempos de vuelta de los pilotos
tiempo_a_1 = 78.2
tiempo_a_2 = 79.0
tiempo_a_3 = 78.5
tiempo_a_4 = 77.8

tiempo_b_1 = 78.0
tiempo_b_2 = 80.2
tiempo_b_3 = 77.5
tiempo_b_4 = 79.5

# Media Piloto A
suma_a = tiempo_a_1 + tiempo_a_2 + tiempo_a_3 + tiempo_a_3 + tiempo_a_4
media_a = (tiempo_a_1 + tiempo_a_2 + tiempo_a_3 + tiempo_a_4)/4

# Media Piloto B
suma_b = tiempo_b_1 + tiempo_b_2 + tiempo_b_3 + tiempo_b_3 + tiempo_b_4
media_b = (tiempo_b_1 + tiempo_b_2 + tiempo_b_3  + tiempo_b_4)/4

print("Media Piloto A:", media_a )
print("Media Piloto B:", media_b )
# Out:
# Media Piloto A: 78.375
# Media Piloto B: 78.8

# %%
# Desvío estándar Piloto A
dif_a_1_media = tiempo_a_1 - media_a
dif_a_2_media = tiempo_a_2 - media_a
dif_a_3_media = tiempo_a_3 - media_a
dif_a_4_media = tiempo_a_4 - media_a

varianza_a = (dif_a_1_media ** 2 + dif_a_2_media ** 2 + dif_a_3_media ** 2 + dif_a_4_media ** 2  ) /4
desvio_a = varianza_a ** 0.5

# Desvío estándar Piloto B
dif_b_1_media = tiempo_b_1 - media_b
dif_b_2_media = tiempo_b_2 - media_b
dif_b_3_media =  tiempo_b_3 - media_b
dif_b_4_media =  tiempo_b_4 - media_b

varianza_b = (dif_b_1_media ** 2 + dif_b_2_media ** 2 + dif_b_3_media ** 2 + dif_b_4_media ** 2  ) /4
desvio_b = varianza_b ** 0.5

print("Desvío estándar Piloto A:", desvio_a )
print("Desvío estándar Piloto B:", desvio_b)
# Out:
# Desvío estándar Piloto A: 0.43803538669838143
# Desvío estándar Piloto B: 1.093160555453773

# %% [markdown]
# 📌 Preguntas:
#
# 1. ¿Cuál piloto es el más rápido? ¿Qué medida (media o desvío) te da esta información?
# 2. ¿Cuál piloto es el más consistente? ¿Qué medida (media o desvío) te da esta información?

# %% [markdown]
# ✏️ Respuestas:
#
# 1. El piloto mas rapido es el A. La media
# 2. El A. El desvio.

# %% [markdown]
# A partir de tus respuestas, determiná el piloto más rápido y el más consistente comparando las medidas que correspondan:

# %%
# Determiná el piloto más rápido
if media_a < media_b:
    piloto_rapido = "Piloto A"
else:
    piloto_rapido = "Piloto B"

# Determiná el piloto más consistente
if desvio_a < desvio_b:
    piloto_consistente = "Piloto A"
else:
    piloto_consistente = "Piloto B"

print("El piloto más rápido es:", piloto_rapido )
print("El piloto más consistente es:",piloto_consistente )
# Out:
# El piloto más rápido es: Piloto A
# El piloto más consistente es: Piloto A

# %% [markdown]
# ## 📝 Ejercicio 9

# %% [markdown]
# En una encuesta realizada en una empresa se recopilaron las horas de trabajo semanales de 10 empleados.
#
# Los datos son: 40, 42, 38, 41, 39, 42, 40, 41, 39, 40.
#
# Calculá la **media**, la **mediana**, el **rango** y el **desvío estándar** de las horas trabajadas por semana:

# %%
# Datos de horas trabajadas
import math

horas1 = 40
horas2 = 42
horas3 = 38
horas4 = 41
horas5 = 39
horas6 = 42
horas7 = 40
horas8 = 41
horas9 = 39
horas10 =40

# Media
suma_horas = horas1 + horas2 + horas3 + horas4 + horas5 + horas6 + horas7 + horas8 + horas9 + horas10
media_horas = suma_horas /10

# Mediana
total_horas = [horas1,horas2,horas3,horas4,horas5,horas6,horas7,horas8,horas9,horas10]
total_horas.sort()
lista_ordenada = total_horas
print(total_horas)
#mediana =

posicion_mediana = (10 + 1) // 2

if posicion_mediana == 1:
    mediana_horas = (lista_ordenada[0] + lista_ordenada[1])/2
elif posicion_mediana == 2:
    mediana_horas = (lista_ordenada[2] + lista_ordenada[3])/2
elif posicion_mediana == 3:
     mediana_horas = (lista_ordenada[3] + lista_ordenada[4])/2
elif posicion_mediana == 4:
    mediana_horas = (lista_ordenada[4] + lista_ordenada[5])/2
elif posicion_mediana == 5:
    mediana_horas = (lista_ordenada[5] + lista_ordenada[6])/2
elif posicion_mediana == 6:
    mediana_horas = (lista_ordenada[6] + lista_ordenada[7])/2
elif posicion_mediana == 7:
    mediana_horas = (lista_ordenada[7] + lista_ordenada[8])/2
elif posicion_mediana == 8:
    mediana_horas = (lista_ordenada[8] + lista_ordenada[9])/2
#else:
   # mediana_horas = (lista_ordenada[0] + lista_ordenada[1])/2

# Rango
max_horas = horas2
min_horas = horas3
rango_horas = max_horas - min_horas

# Desvío estándar
dif_horas1_media2 = (horas1 - media_horas) ** 2
dif_horas2_media2 = (horas2 - media_horas) ** 2
dif_horas3_media2 =  (horas3 - media_horas) ** 2
dif_horas4_media2 =  (horas4 - media_horas) ** 2
dif_horas5_media2 =   (horas5 - media_horas) ** 2
dif_horas6_media2 =   (horas6 - media_horas) ** 2
dif_horas7_media2 =    (horas7 - media_horas) ** 2
dif_horas8_media2 =     (horas8 - media_horas) ** 2
dif_horas9_media2 =     (horas9 - media_horas) ** 2
dif_horas10_media2 =     (horas10 - media_horas) ** 2

varianza_horas = (dif_horas1_media2 + dif_horas2_media2 + dif_horas3_media2 + dif_horas4_media2 +
                  dif_horas5_media2 + dif_horas6_media2 + dif_horas7_media2 + dif_horas8_media2 +
                  dif_horas8_media2 + dif_horas9_media2 + dif_horas10_media2) / 10
desvio_horas = math.sqrt(varianza_horas)

# Resultados
print("Media:", media_horas)
print("Mediana:", mediana_horas )
print("Rango:", rango_horas )
print("Desvío estándar:", desvio_horas )
# Out:
# [38, 39, 39, 40, 40, 40, 41, 41, 42, 42]
# Media: 40.2
# Mediana: 40.5
# Rango: 4
# Desvío estándar: 1.274362585765919

# %% [markdown]
# 📌 Preguntas:
# 1. ¿Qué te dice la relación entre la media y la mediana sobre la distribución de los datos?
# 2. ¿Cuál es la variabilidad de las horas trabajadas? ¿Qué indica el desvío estándar?

# %% [markdown]
# ✏️ Respuestas:
#
# 1. Que la distribucion de los datos es pareja y no hay datos que se alejen demasiado del centro (valores atipicos).
# 2. La variabilidad de las horas trabajadas es de 4 horas. El desvio estandar indica que tan lejos o cerca del promedio estan de las horas trabajadas. Si el desvio es bajo significa que casi todos los empleados trabajaron casi lo mismo. Si el desvio es alto significa que los empleados tienen una cantidad de horas significativa de diferencia trabajadas (algunos trabajaron mas que el promedio)

# %% [markdown]
# ## 📝 Ejercicio 10

# %% [markdown]
# En una empresa se registraron las duraciones (en años) de 10 productos. Los valores de duración son los siguientes:
#
# 📌 **Datos antes de agregar el producto defectuoso:**
#
# - 6, 7, 7, 8, 7, 7, 7, 6, 8, 7
#
# Luego, se introduce un nuevo producto defectuoso con una duración de 2 años. Los nuevos datos son:
#
# 📌 **Datos después de agregar el producto defectuoso:**
#
# - 6, 7, 7, 8, 7, 7, 7, 6, 8, 7, **2**

# %% [markdown]
# Tareas:
# 1. Calculá la **media** y la **mediana** de las duraciones antes y después de agregar el producto defectuoso.
# 2. Calculá el **rango** y el **desvío estándar** en ambos casos.

# %%
# Escribí tu código acá
import math

Duracion_en_años_de_los_producto_defectuoso = [6, 7, 7, 8, 7, 7, 7, 6, 8, 7]

Duracion_en_años_de_los_producto_defectuoso.sort()

lista_ordenada = Duracion_en_años_de_los_producto_defectuoso

print(Duracion_en_años_de_los_producto_defectuoso)

mediana = (lista_ordenada[4] + lista_ordenada[5])/2
media = (lista_ordenada[0] + lista_ordenada[1] + lista_ordenada[2] + lista_ordenada[3] +
         lista_ordenada[4] + lista_ordenada[5] + lista_ordenada[6] + lista_ordenada[7] + lista_ordenada[8] + lista_ordenada[9] )/10



varianza = (lista_ordenada[0] - media)**2 + (lista_ordenada[1] - media)**2 - (lista_ordenada[2] - media)**2 + (lista_ordenada[3]- media)**2 + (lista_ordenada[4] - media) **2
+ (lista_ordenada[5] - media) **2  + (lista_ordenada[6] - media) **2 + (lista_ordenada[7] - media) **2 + (lista_ordenada[8] - media) **2 + (lista_ordenada[9] - media) **2

#print(varianza)
desvio_estandar = math.sqrt(varianza)


rango = lista_ordenada[-1] - lista_ordenada[0] #El rango se calcula haciend el valor (dato) maximo menos el valor minimo (dato)

print(f"La mediana es: {mediana}")
print(f"La media es: {media}")
print(f"El desvio estandar es: {desvio_estandar}")
print(f"El rango es : {rango}")


print("\n")



Duracion_en_años_de_los_producto_defectuoso.insert(0,2)

print(Duracion_en_años_de_los_producto_defectuoso)

mediana_con_el_ultimo_producto = lista_ordenada[6]
media_con_el_ultimo_producto = (lista_ordenada[0] + lista_ordenada[1] + lista_ordenada[2] + lista_ordenada[3] +
         lista_ordenada[4] + lista_ordenada[5] + lista_ordenada[6] + lista_ordenada[7] + lista_ordenada[8] + lista_ordenada[9] + lista_ordenada[10] )/11

varianza = (lista_ordenada[0] - media)**2 + (lista_ordenada[1] - media)**2 - (lista_ordenada[2] - media)**2 + (lista_ordenada[3]- media)**2 + (lista_ordenada[4] - media) **2
+ (lista_ordenada[5] - media) **2  + (lista_ordenada[6] - media) **2 + (lista_ordenada[7] - media) **2 + (lista_ordenada[8] - media) **2 + (lista_ordenada[9] - media) **2 + (lista_ordenada[10] - media) **2

desvio_estandar = math.sqrt(varianza)


rango = lista_ordenada[-1] - lista_ordenada[0] #El rango se calcula haciend el valor (dato) maximo menos el valor minimo (dato)

print(f"La mediana es: {mediana}")
print(f"La media es: {media}")
print(f"El desvio estandar es: {desvio_estandar}")
print(f"El rango es : {rango}")

#duraciones_con_producto_nuevo =
# Out:
# [6, 6, 7, 7, 7, 7, 7, 7, 8, 8]
# La mediana es: 7.0
# La media es: 7.0
# El desvio estandar es: 1.4142135623730951
# El rango es : 2
#
#
# [2, 6, 6, 7, 7, 7, 7, 7, 7, 8, 8]
# La mediana es: 7.0
# La media es: 7.0
# El desvio estandar es: 5.0
# El rango es : 6

# %% [markdown]
# 📌 Preguntas:
# 1. ¿Cómo cambia la tendencia central (media y mediana) al agregar el producto defectuoso?
# 2. ¿Qué sucede con la dispersión (rango y desviación estándar)?

# %% [markdown]
# ✏️ Respuestas:
#
# 1. No cambian.
# 2. Se vuelven mas grandes. El rango pasa de 2 a 6 y el desvio estandar de √2 a 5
