# %% [markdown]
# <a href="https://colab.research.google.com/github/juan-lawrie/Repaso-Ciencias-de-datos/blob/main/Copia_de_02_%5BPr%C3%A1ctica%5D_Expresiones_l%C3%B3gicas_y_ramificaci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📌 Tema 2 Práctica: Expresiones lógicas y ramificación

# %% [markdown]
# ❗Antes de comenzar con la clase, hacete una copia de este documento así podés editarlo y guardar los cambios.
#
# Hacé clic acá arriba, donde dice "Copiar en Drive".
#
# Luego seguís trabajando en esa copia y te queda todo guardado en tu Drive.

# %% [markdown]
# ---

# %% [markdown]
# ## 📝 Ejercicio 1

# %% [markdown]
# Se tiene la siguiente información de un estudiante universitario:

# %%
nombre_completo = "Juan Pérez"
edad = 23
ciudad_residencia = "Paraná"
carrera = "Ciencia de Datos"
promedio = 8.2
materias_aprobadas = 12
tiene_beca = False
realizo_practicas = True

if edad > 20:
  print(f"Su edad es: {edad}")
if ciudad_residencia or "Santa Fe":
  print(f"Vive en {ciudad_residencia}")
if promedio > 8 and materias_aprobadas >= 10:
  print(f"El promedio es: {promedio} y las materias aprobadas son {materias_aprobadas}")
if carrera != "Derecho":
  print(f"Esta en la carrera de {carrera}")
if tiene_beca or realizo_practicas:
  print(f"No tiene beca pero realizo practicas: {tiene_beca} y {realizo_practicas} ")
# Out:
# Su edad es: 23
# Vive en Paraná
# El promedio es: 8.2 y las materias aprobadas son 12
# Esta en la carrera de Ciencia de Datos
# No tiene beca pero realizo practicas: False y True

# %% [markdown]
# Definí las expresiones lógicas adecuadas para verificar las siguientes condiciones:
#
# 1. Tiene más de 20 años.
# 2. Reside en Santa Fe o en Paraná.
# 3. Tiene un promedio mayor a 8.0 y ha aprobado al menos 10 materias.
# 4. No está en la carrera de Derecho.
# 5. No tiene beca pero realizó prácticas.

# %% [markdown]
# ✏️ Respuestas:
#
# 1. Mayor que >
# 2. or
# 3. Mayor que >, and y mayor o igual que >=
# 4. Distinto de !=
# 5. or

# %% [markdown]
# En la celda de abajo, probá cada expresión que definiste escribiéndolas dentro de los `print()`:

# %%
print(f"Su edad es: {edad}")
print(f"Vive en {ciudad_residencia}")
print(f"El promedio es: {promedio} y las materias aprobadas son {materias_aprobadas}")
print(f"Esta en la carrera de {carrera}")
print(f"No tiene beca pero realizo practicas: {tiene_beca} y {realizo_practicas} ")
# Out:
# Su edad es: 23
# Vive en Paraná
# El promedio es: 8.2 y las materias aprobadas son 12
# Esta en la carrera de Ciencia de Datos
# No tiene beca pero realizo practicas: False y True

# %% [markdown]
# ## 📝 Ejercicio 2

# %% [markdown]
# Observá el código en la celda a continuación:

# %%
edades =[ ]
precio_base = 5000



for edades in range (8,90,4):

  if edades < 18:
      descuento = precio_base * 0.05

  elif 18 <= edades and edades <= 60:
      descuento = precio_base * 0.03
  elif edades > 60:
      descuento = precio_base * 0.07
  else:
      descuento = 0
  print(f"El descuento es {descuento} para edad: {edades}",f"El precio final es {precio_base - descuento} para edad: {edades}")
# Out:
# El descuento es 250.0 para edad: 8 El precio final es 4750.0 para edad: 8
# El descuento es 250.0 para edad: 12 El precio final es 4750.0 para edad: 12
# El descuento es 250.0 para edad: 16 El precio final es 4750.0 para edad: 16
# El descuento es 150.0 para edad: 20 El precio final es 4850.0 para edad: 20
# El descuento es 150.0 para edad: 24 El precio final es 4850.0 para edad: 24
# El descuento es 150.0 para edad: 28 El precio final es 4850.0 para edad: 28
# El descuento es 150.0 para edad: 32 El precio final es 4850.0 para edad: 32
# El descuento es 150.0 para edad: 36 El precio final es 4850.0 para edad: 36
# El descuento es 150.0 para edad: 40 El precio final es 4850.0 para edad: 40
# El descuento es 150.0 para edad: 44 El precio final es 4850.0 para edad: 44
# El descuento es 150.0 para edad: 48 El precio final es 4850.0 para edad: 48
# El descuento es 150.0 para edad: 52 El precio final es 4850.0 para edad: 52
# ...

# %% [markdown]
# 📌 Preguntas:
#
# 1. ¿Cuántas variables y tipos de datos se utilizan en el código?
# 2. ¿Qué operadores relacionales, lógicos y estructuras de control se emplean?
# 4. Explicá con tus palabras lo que hace el código.

# %% [markdown]
# ✏️ Respuestas:
#
# 1. Son 4 variables y a dos tipos de datos, enteros y flotantes.
# 2. El igual (=), el menor que (<) y el menor o igual que(<=), if, elif y else
# 3. En base a dos variables edad y precio_base se crea una estructura de control con if, elif y else, usando tambien operadores logicos y relacionales que analizan la edad y el precio_base y en base a eso ven el descuento a aplicar o si no le aplican ningun descuento. El descuento depende de la edad y es igual a descuento = precio_base * (depende en que condicion cae segun la edad) puede no caer en ninguna de las tres y pasa al else.

# %% [markdown]
# Calculá el precio final a pagar por el pasaje:

# %%
precio_base = 5000

precio_final = precio_base - descuento

edades =[ ]

for edades in range (8,90,4):

  if edades < 18:
      descuento = precio_base * 0.05

  elif 18 <= edades and edades <= 60:
      descuento = precio_base * 0.03
  elif edades > 60:
      descuento = precio_base * 0.07

  else:
      descuento = 0
  print(f"El descuento es {descuento} para edad: {edades} \n ", f"El precio final es {precio_base - descuento} para edad: {edades}")
# Out:
# El descuento es 250.0 para edad: 8
#   El precio final es 4750.0 para edad: 8
# El descuento es 250.0 para edad: 12
#   El precio final es 4750.0 para edad: 12
# El descuento es 250.0 para edad: 16
#   El precio final es 4750.0 para edad: 16
# El descuento es 150.0 para edad: 20
#   El precio final es 4850.0 para edad: 20
# El descuento es 150.0 para edad: 24
#   El precio final es 4850.0 para edad: 24
# El descuento es 150.0 para edad: 28
#   El precio final es 4850.0 para edad: 28
# El descuento es 150.0 para edad: 32
#   El precio final es 4850.0 para edad: 32
# El descuento es 150.0 para edad: 36
#   El precio final es 4850.0 para edad: 36
# El descuento es 150.0 para edad: 40
#   El precio final es 4850.0 para edad: 40
# El descuento es 150.0 para edad: 44
#   El precio final es 4850.0 para edad: 44
# El descuento es 150.0 para edad: 48
#   El precio final es 4850.0 para edad: 48
# El descuento es 150.0 para edad: 52
#   El precio final es 4850.0 para edad: 52
# ...

# %% [markdown]
# Mostrá los resultados:

# %%
precio_base = 5000
precio_final = precio_base - descuento
edades =[ ]

for edades in range (8,90,4):

  if edades < 18:
      descuento = precio_base * 0.05

  elif 18 <= edades and edades <= 60:
      descuento = precio_base * 0.03
  elif edades > 60:
      descuento = precio_base * 0.07

  else:
      descuento = 0
  print(f"El descuento es {descuento} para edad: {edades} \n ", f"El precio final es {precio_base - descuento} para edad: {edades}")
# Out:
# El descuento es 250.0 para edad: 8
#   El precio final es 4750.0 para edad: 8
# El descuento es 250.0 para edad: 12
#   El precio final es 4750.0 para edad: 12
# El descuento es 250.0 para edad: 16
#   El precio final es 4750.0 para edad: 16
# El descuento es 150.0 para edad: 20
#   El precio final es 4850.0 para edad: 20
# El descuento es 150.0 para edad: 24
#   El precio final es 4850.0 para edad: 24
# El descuento es 150.0 para edad: 28
#   El precio final es 4850.0 para edad: 28
# El descuento es 150.0 para edad: 32
#   El precio final es 4850.0 para edad: 32
# El descuento es 150.0 para edad: 36
#   El precio final es 4850.0 para edad: 36
# El descuento es 150.0 para edad: 40
#   El precio final es 4850.0 para edad: 40
# El descuento es 150.0 para edad: 44
#   El precio final es 4850.0 para edad: 44
# El descuento es 150.0 para edad: 48
#   El precio final es 4850.0 para edad: 48
# El descuento es 150.0 para edad: 52
#   El precio final es 4850.0 para edad: 52
# ...

# %% [markdown]
# ## 📝 Ejercicio 3

# %% [markdown]
# A continuación, se presentan varias expresiones. Respondé las siguientes preguntas para cada una de ellas:
#
# 1. ¿En qué orden se realizan las operaciones?
# 2. Identificá los operadores y los operandos.
#
# Expresiones:
# 1. `a + b > 15 and a % c == 0`
# 2. `b * c + 3 != a or a / 2 > b`
# 3. `a - b < d / c and a + b * c != 20`
# 4. `a % 3 == 0 or c + d > 10 and 2 * c < a`
# 5. `not (a + b > 0.5) and c * d == a + b`

# %% [markdown]
# ✏️ Respuestas:
#
# 1. Primero se calcula el modulo, despues la suma, despues se analiza el mayor y por ultimo el and. Operandos: a , b, 15, c, 0. Operadores: +, >, and, %, ==.
# 2. Primero se calcula la multiplicacion, despues la division, despues la suma, despues se analiza el distinto de, despues se analiza el mayor que y por ultimo se hace el or . Operandos: b, c, 3, a, 2, . Operadores: *, +, !=, or, /, >
# 3. Primero se hace la division, despues la multiplicacion. despues la resta, despues la suma, despues el menor que, despues el distinto de y por ultimo el and. Operandos: b, c, d, a, 20. Operadores: -, <, /, and, +, *, !=.
# 4. Primero se calcula el modulo, despues la multiplicacion, despues la suma, despues el mayor que, despues el menor que, despues el and y por ultimo or. Operandos: d, c, 3, a, 2,10. Operadores: %, ==, or, +, >, and, *, <.
# 5. Primero se hace lo que esta dentro del parentesis empezando por la suma siguiendo por el mayor que, luego se hace el not, luego se calcula la multiplicacion, despues la multiplicacion, se analiza la igualdad y por ultimo se realiza el and. Operandos: a, b, 0.5, c, d, a, b. Operadores: not, +, >, and, *, ==, +

# %% [markdown]
# ## 📝 Ejercicio 4

# %% [markdown]
# Una empresa necesita calcular el salario total de un empleado.
#
# El salario total se compone de un salario base y un bono adicional si ha cumplido sus objetivos.
#
# Corregí todos los errores en el siguiente código para que el cálculo del salario sea correcto:

# %%
salario_base = 500000
bono = 100000
objetivos_cumplidos = True

if objetivos_cumplidos:
    print(salario_base + bono)


else:

  print("El salario total es:", salario_base)
# Out:
# 600000

# %% [markdown]
# Modificá el código para que el cálculo del salario no requiera el uso de un `else`:

# %%
# Escribí tu código acá

salario_base = 500000
bono = 100000

objetivos_cumplidos = False

if objetivos_cumplidos:
    print(salario_base + bono)

match objetivos_cumplidos:
  case False:


    print("El salario total es:", salario_base)
# Out:
# El salario total es: 500000

# %% [markdown]
# ## 📝 Ejercicio 5

# %% [markdown]
# Un sistema de riego automático para un jardín debe activarse si:
#
# - La humedad del suelo es menor al 30%.
#
# - No está lloviendo.
#
# - La temperatura exterior es mayor a 25°C.
#
# Completá el código para verificar corresponde activar el riego:

# %%
humedad_suelo = 29
lloviendo = False
temperatura_exterior = 28

if humedad_suelo < 30 and lloviendo == False and temperatura_exterior > 25 :
  print("Activar riego")
#if lloviendo == False:
#  print("Activar riego")
#if temperatura_exterior > 25:
#  print("Activar riego")

else:
     print("Riego desactivado")
# Out:
# Activar riego

# %% [markdown]
# Modificá el código para combinar las condiciones en un solo `if`:

# %%
# Escribí tu código acá
if humedad_suelo < 30 and lloviendo == False and temperatura_exterior > 25 :
  print("Activar riego")

else:
     print("Riego desactivado")
# Out:
# Activar riego

# %% [markdown]
# ## 📝 Ejercicio 6

# %% [markdown]
# Un banco evalúa si una persona es elegible para un préstamo según las siguientes condiciones:
# - **Aprobado**: si el salario es mayor o igual a \$500.000 y tiene más de 2 años de antigüedad en su trabajo.
# - **Aprobado con restricciones**: si tiene un salario mayor o igual a \$300.000 pero menor a \$500.000 y al menos 1 año de antigüedad.
# - **Rechazado**: en cualquier otro caso.
#
# Corregí los errores en el siguiente código para que la evaluación del préstamo sea correcta:

# %%
salario = 500001
antiguedad = 1

if salario >= 500000 and antiguedad > 2:
    estado = "Aprobado"

elif salario >= 300000 and salario < 500000 and antiguedad >= 1:
  estado = "Aprobado con restricciones"


else:
  estado = "Rechazado"
print(f"Estado del préstamo: {estado}")
# Out:
# Estado del préstamo: Rechazado

# %% [markdown]
# Modificá los valores de salario y antiguedad para probar distintos escenarios. Por ejemplo:
#
# - Caso 1: salario de \$510.000 y antigüedad de 3 años.
# - Caso 2: salario de \$350.000 y antigüedad de 1 año.
# - Caso 3: salario de \$250.000 y antigüedad de 2 años.
#
# ¿Qué resultado esperás en cada caso? Probá estas combinaciones y verificá si el código funciona correctamente.

# %% [markdown]
# ## 📝 Ejercicio 7

# %% [markdown]
# Una atleta participa en tres rondas de una competencia, obteniendo distintas puntuaciones. Se deben calcular:
#
# Tareas:
# - Calculá la **mejor ronda** (máxima puntuación) y la **peor ronda** (mínima puntuación).
# - Calculá la **puntuación media** de las tres rondas.
# - Calculá la **puntuación media máxima**, descartando la peor puntuación y promediando las dos mejores.
#
# Las puntuaciones registradas fueron: 8.5, 9.2 y 7.8.
#
# Completá el código para realizar los cálculos:

# %%
# Puntuaciones en tres rondas
p1 = 8.5
p2 = 9.2
p3 = 7.8

# %%
# Calculá la mejor ronda (máximo)
p1 = 8.5
p2 = 9.2
p3 = 7.8
if p1 > p2 and p1 > p3:
    mejor_ronda = p3
elif p2 > p1:
    mejor_ronda = p2
else:
    mejora_ronda = p1

print("Mejor ronda:", mejor_ronda)
# Out:
# Mejor ronda: 9.2

# %%
# Calculá la peor ronda (mínimo)

p1 = 8.5
p2 = 9.2
p3 = 7.8
if p1<p2 and p1<p3:
    peor_ronda = p1
elif p2<p1 and p2<p3:
    peor_ronda = p2
else:
    peor_ronda = p3

print("Peor ronda:", peor_ronda)
# Out:
# Peor ronda: 7.8

# %%
# Puntuación media

p1 = 8.5
p2 = 9.2
p3 = 7.8
puntuacion_media = (p2 + p1 + p3) / 3

# Puntuación media máxima (descartando la peor puntuación)
puntuacion_media_maxima = (p2 + p1 + p3 - peor_ronda) / 2

print(f"Puntuación media: {puntuacion_media}" )
print(f"Puntuación media máxima: {puntuacion_media_maxima}" )
# Out:
# Puntuación media: 8.5
# Puntuación media máxima: 8.85

# %% [markdown]
# ## 📝 Ejercicio 8

# %% [markdown]
# Un laboratorio ha realizado un estudio clínico para evaluar la efectividad de una vacuna contra un virus.
#
# Los datos recopilados son los siguientes:
# - Infectados en el grupo de la vacuna: 20
# - Infectados en el grupo del placebo: 100
#
# Se sabe que la cantidad de participantes en cada grupo fue la misma y se desea calcular la efectividad de la vacuna utilizando la fórmula:
#
# $$
# \text{Efectividad} = \left(1 − \frac{\text{Infectados en el grupo de la vacuna}}{\text{Infectados en el grupo del placebo}}\right)
#  \times 100
# $$
#
# Completá el código para calcular la efectividad de la vacuna:

# %%
#from math import *
infectados_vacuna = 20
infectados_placebo = 100

efectividad = (1-infectados_vacuna/infectados_placebo)*100


print(f"Efectividad:{efectividad}")

def efectividad_vacuna():
  return (1-infectados_vacuna/infectados_placebo)*100
#print(f"La efectividad de la vacuna es {infectados_vacuna(20)}{infectados_placebo(100)}")
print("La efectividad de la vacuna es:")
print(efectividad_vacuna())
# Out:
# Efectividad:80.0
# La efectividad de la vacuna es:
# 80.0

# %% [markdown]
# Se considera que la vacuna será aprobada si la efectividad es mayor al 50%.
#
# Determiná si la vacuna cumple con los requisitos para su aprobación:

# %%
vacuna_aprobada = efectividad

if vacuna_aprobada > 50:

  print("Vacuna aprobada")
else:
        print("Vacuna Rechazada")
# Out:
# Vacuna aprobada

# %% [markdown]
# ## 📝 Ejercicio 9

# %% [markdown]
# Un equipo de fútbol ha finalizado su participación en la temporada y ahora es momento de analizar cómo le ha ido.
#
# Las reglas para la asignación de puntos son:
# - Victoria: 3 puntos
# - Empate: 1 punto
# - Derrota: 0 puntos
#
# A continuación tenemos los datos del equipo al finalizar la temporada:
# - Victorias: 15
# - Empates: 3
# - Derrotas: 2
# - Goles marcados: 31
#
# Tareas:
# - Calculá el total de partidos jugados.
# - Calculá el total de puntos obtenidos.
# - Calculá el porcentaje de victorias.
#
# Completá el código para realizar los cálculos:

# %%
victorias = 15
empates = 3
derrotas = 2
goles_marcados = 31

partidos_jugados = victorias + empates + derrotas
puntos_obtenidos = victorias * 3 + empates
porcentaje_victorias = victorias/partidos_jugados

print(f"Partidos jugados: {partidos_jugados}")
print(f"Puntos obtenidos: {puntos_obtenidos }")
print(f"Porcentaje de Victorias: {porcentaje_victorias:.1%}")
# Out:
# Partidos jugados: 20
# Puntos obtenidos: 48
# Porcentaje de Victorias: 75.0%

# %% [markdown]
# Si la liga otorga una bonificación de 5 puntos si la media de goles marcados es mayor a 1.5.
#
# Calculá la media de goles marcados dividiendo los goles marcados entre los partidos jugados.
#
# Luego, verificá si recibe la bonificación y calculá los puntos obtenidos:

# %%
empates = 3
victorias = 15
derrotas = 2
goles_marcados = 31
partidos_jugados = victorias + empates + derrotas
puntos_obtenidos = victorias * 3 + empates

media_goles_marcados = goles_marcados / partidos_jugados
bonificacion = 5

if media_goles_marcados > 1.5:
    print(f"Media de goles marcados: {media_goles_marcados}")
    print(f"Puntos obtenidos luego de la bonificación: {puntos_obtenidos + bonificacion}")

else:

    print(f"La media {media_goles_marcados} no supera 1.5")
# Out:
# Media de goles marcados: 1.55
# Puntos obtenidos luego de la bonificación: 53

# %% [markdown]
# Según los estándares de la institución, el rendimiento global se clasifica de la siguiente manera:
#
# - **Excelente**: si el equipo obtiene más de 50 puntos.
# - **Aceptable**: si el rendimiento está entre 30 y 50 puntos
# - **Mejorable**: si el rendimiento es menor de 30 puntos.
#
# Verificá si el código está correcto y sino, realizá los ajustes necesarios para que funcione correctamente:

# %%
puntos_obtenidos + bonificacion
if puntos_obtenidos < 50:
    rendimiento = "Excelente"
elif  puntos_obtenidos == 50 or puntos_obtenidos >= 30:
    rendimiento = "Aceptable"
else:
    puntos_obtenidos < 30
    rendimiento  = "Mejorable"

print(f"Rendimiento del equipo:{rendimiento}")
# Out:
# Rendimiento del equipo:Excelente

# %% [markdown]
# ## 📝 Ejercicio 10

# %% [markdown]
# Una empresa está evaluando abrir una nueva sucursal en un barrio específico.
#
# La decisión dependerá de algunas condiciones que involucran sus propias ganancias y las de su competencia.
#
# La empresa abrirá la sucursal si:
# - Su ganancia esperada es de al menos 15\%.
# - O bien, su competidor no abre una sucursal en el mismo barrio.
#
# El competidor abrirá una sucursal si:
# - Su participación en el barrio supera el 20\% de los clientes.
#
#
# Los datos disponibles son:
# - La empresa tiene una ganancia esperada del 7\%.
# - El competidor tiene una participación del 15\% de los clientes del barrio.
#
# Completá el código para determinar si la empresa abrirá o no la sucursal:

# %%
ganancia_empresa = int(input("Ganancia de la empresa: "))
participacion_rival = 15
competidor_no_abre_sucursal_en_el_mismo_barrio = bool(input("Escribir algo para True o dejar vacio para False: "))

abre_sucursal_rival = bool(input("Escribir algo para True o dejar vacio para False: "))

# Verificar si la empresa abrirá la sucursal
if  ganancia_empresa >= 15 or competidor_no_abre_sucursal_en_el_mismo_barrio :

    print("La empresa abre la sucursal: ")
else:
    print("No abre sucursal")

# Verificar si el competidor abrirá su sucursal
if abre_sucursal_rival:
  print("El rival abre sucursal")
else:
 print ("El rival no abre sucursal")

print(f"¿La empresa abrirá una sucursal? {ganancia_empresa >= 15 or competidor_no_abre_sucursal_en_el_mismo_barrio}")
print(f"¿El competidor abrirá una sucursal? {abre_sucursal_rival}")
# Out:
# Ganancia de la empresa: 10
# Escribir algo para True o dejar vacio para False: True
# Escribir algo para True o dejar vacio para False:
# La empresa abre la sucursal:
# El rival no abre sucursal
# ¿La empresa abrirá una sucursal? True
# ¿El competidor abrirá una sucursal? False

# %% [markdown]
# 📌 Preguntas:
#
# 1. ¿Qué pasaría si la ganancia de la empresa fuera del 18\%? ¿Cambiaría la decisión?
# 2. ¿Cómo afectaría la decisión si cambio en la participación del rival superara el 20\%?

# %% [markdown]
# ✏️ Respuestas:
#
# 1. La empresa abriria la sucursal si el rival no abriria una sucursal en el barrio
# 2. El rival abriria una sucursal en el barrio

# %% [markdown]
# ---

# %% [markdown]
# Ahora es momento de analizar los costos y los ingresos esperados de la empresa para la nueva sucursal.
#
# Se sabe que:
# - El costo operativo de la sucursal es de \$5.000.000.
# - Actualmente, hay 3 sucursales de la competencia en la zona.
# - El ingreso medio mensual estimado por cliente es de \$20.000.
# - Si el número total de sucursales en un radio de 5 km es mayor a 2, los costos operativos aumentan en un 10\%.
# - Se estima que la nueva sucursal captará 300 clientes al mes.
#
# Tareas:
# - Calculá los costos totales considerando las condiciones dadas.
# - Calculá los ingresos esperados.
# - Determiná si la empresa podrá cubrir los costos con los ingresos proyectados.

# %%
# Escribí tu código acá

costo_operativo = 5000000
ingreso_medio_mensual_por_cliente = 20000
numero_sucursales = 3
radio_km = float(input("El radio en Km es: "))
diez_porciento_costos_operativos = (costo_operativo * 10) / 100
clientes_estimados_al_mes = 300
calculo_ingreso_medio_mensual_por_cliente = ingreso_medio_mensual_por_cliente * clientes_estimados_al_mes


if numero_sucursales > 2 and radio_km <= 5:
  aumento_costos_operativos = diez_porciento_costos_operativos + costo_operativo
  print(aumento_costos_operativos)
else:
  print("No hay aumento de los costos operativos")
